# %%
data_dir = "../../data/trec_covid_topic_modelling"
model_dir = "../../models/trec_covid_topic_modelling"

# %% [markdown]
# # LDA Model
# First read data

# %%
import csv
import os
import sys
import gensim
import numpy as np
csv.field_size_limit(sys.maxsize)

f_tokenized_path = "/home/tfink/data/kodicare/trec-covid/TREC-COVID_sample_content.csv.tokenized.txt"
f_comp_tokenized_path = os.path.join(data_dir, "abcnews-date-text.csv.tokenized.txt")
num_topics = 30
passes = 40
iterations = 5000
minimum_probability = 0.05


def read_tokenized(path, batch_size = None):
    with open(path, "r") as fp:
        reader = csv.reader(fp, delimiter=",", quotechar='"')
        batch = []
        #for line in tqdm(reader, desc="batch"):
        for line in reader:
            cord_uid, doc_text_tokenized = line
            doc_tokens = doc_text_tokenized.split(" ")
            if batch_size:
                batch.append(doc_tokens)
                if len(batch) == batch_size:
                    yield batch
                    batch = []
            else:
                yield doc_tokens
        
        if len(batch) > 0:
            yield batch

# %%
# TREC Covid docs
processed_docs = list(read_tokenized(f_tokenized_path, batch_size=None))
print(processed_docs[0][:10])

# comparison docs from the news domain
processed_docs_comp = list(read_tokenized(f_comp_tokenized_path, batch_size=None))
print(processed_docs_comp[0][:10])
# Out:
# ['clinical', 'feature', 'culture', 'prove', 'mycoplasma', 'pneumoniae', 'infection', 'king', 'abdulaziz', 'university']
# ['decide', 'community', 'broadcasting', 'licence']

# %%
dictionary = gensim.corpora.Dictionary(processed_docs+processed_docs_comp)
dictionary.filter_extremes(no_below=15, no_above=0.5, keep_n=100000)
print(len(dictionary))
list(dictionary.items())[:10]
# Out:
# 21272
# [(0, '<NUM>'),
#  (1, 'abscess'),
#  (2, 'absence'),
#  (3, 'access'),
#  (4, 'accord'),
#  (5, 'account'),
#  (6, 'accounting'),
#  (7, 'acquire'),
#  (8, 'acute'),
#  (9, 'additionally')]

# %%
from gensim import models

def create_corpus(docs):
    bow_corpus = [dictionary.doc2bow(doc) for doc in docs]
    bow_doc_0 = bow_corpus[0]
    for i in range(len(bow_doc_0)):
        print("Word {} (\"{}\") appears {} time.".format(bow_doc_0[i][0], 
                                                dictionary[bow_doc_0[i][0]], 
    bow_doc_0[i][1]))

    tfidf = models.TfidfModel(bow_corpus)
    corpus_tfidf = tfidf[bow_corpus]
    return corpus_tfidf

corpus = create_corpus(processed_docs)
corpus_comp = create_corpus(processed_docs_comp)
# Out:
# Word 0 ("<NUM>") appears 134 time.
# Word 1 ("abscess") appears 2 time.
# Word 2 ("absence") appears 2 time.
# Word 3 ("access") appears 2 time.
# Word 4 ("accord") appears 4 time.
# Word 5 ("account") appears 6 time.
# Word 6 ("accounting") appears 2 time.
# Word 7 ("acquire") appears 12 time.
# Word 8 ("acute") appears 8 time.
# Word 9 ("additionally") appears 2 time.
# Word 10 ("adenovirus") appears 2 time.
# Word 11 ("admission") appears 10 time.
# Word 12 ("admit") appears 4 time.
# Word 13 ("adult") appears 14 time.
# Word 14 ("affect") appears 4 time.
# Word 15 ("agar") appears 8 time.
# Word 16 ("age") appears 8 time.
# Word 17 ("agent") appears 2 time.
# Word 18 ("airway") appears 4 time.
# Word 19 ("amplification") appears 2 time.
# Word 20 ("analysis") appears 2 time.
# Word 21 ("and/or") appears 2 time.
# Word 22 ("anemia") appears 4 time.
# Word 23 ("annual") appears 2 time.
# Word 24 ("antibiotic") appears 2 time.
# Word 25 ("approach") appears 2 time.
# Word 26 ("arabia") appears 11 time.
# Word 27 ("area") appears 4 time.
# Word 28 ("arterial") appears 2 time.
# Word 29 ("arthralgia") appears 2 time.
# Word 30 ("arthritis") appears 2 time.
# Word 31 ("aspiration") appears 2 time.
# Word 32 ("assist") appears 2 time.
# Word 33 ("associate") appears 8 time.
# Word 34 ("asthma") appears 4 time.
# Word 35 ("asymptomatic") appears 2 time.
# Word 36 ("atrophy") appears 4 time.
# Word 37 ("attributable") appears 2 time.
# Word 38 ("atypical") appears 4 time.
# Word 39 ("available") appears 4 time.
# Word 40 ("average") appears 2 time.
# Word 41 ("bacteria") appears 2 time.
# Word 42 ("bacterial") appears 4 time.
# Word 43 ("base") appears 4 time.
# Word 44 ("bear") appears 2 time.
# Word 45 ("bed") appears 2 time.
# Word 46 ("bias") appears 2 time.
# Word 47 ("blood") appears 2 time.
# Word 48 ("boarding") appears 2 time.
# Word 49 ("breath") appears 2 time.
# Word 50 ("breathing") appears 4 time.
# Word 51 ("bronchial") appears 6 time.
# Word 52 ("bronchiolitis") appears 14 time.
# Word 53 ("bronchoalveolar") appears 2 time.
# Word 54 ("broth") appears 4 time.
# Word 55 ("camp") appears 2 time.
# Word 56 ("capacity") appears 2 time.
# Word 57 ("cardiopulmonary") appears 2 time.
# Word 58 ("cardiovascular") appears 2 time.
# Word 59 ("care") appears 4 time.
# Word 60 ("case") appears 10 time.
# Word 61 ("categorical") appears 2 time.
# Word 62 ("category") appears 2 time.
# Word 63 ("causative") appears 2 time.
# Word 64 ("cause") appears 14 time.
# Word 65 ("cell") appears 2 time.
# Word 66 ("center") appears 2 time.
# Word 67 ("cerebral") appears 2 time.
# Word 68 ("chain") appears 2 time.
# Word 69 ("change") appears 2 time.
# Word 70 ("characteristic") appears 2 time.
# Word 71 ("chart") appears 6 time.
# Word 72 ("chest") appears 2 time.
# Word 73 ("child") appears 22 time.
# Word 74 ("classic") appears 2 time.
# Word 75 ("classify") appears 2 time.
# Word 76 ("climate") appears 2 time.
# Word 77 ("clinical") appears 16 time.
# Word 78 ("clinically") appears 4 time.
# Word 79 ("clinician") appears 2 time.
# Word 80 ("close") appears 2 time.
# Word 81 ("closed") appears 2 time.
# Word 82 ("coagulation") appears 2 time.
# Word 83 ("collect") appears 2 time.
# Word 84 ("collection") appears 2 time.
# Word 85 ("college") appears 2 time.
# Word 86 ("colonial") appears 2 time.
# Word 87 ("colony") appears 2 time.
# Word 88 ("color") appears 2 time.
# Word 89 ("common") appears 38 time.
# Word 90 ("community") appears 12 time.
# Word 91 ("comorbiditie") appears 30 time.
# Word 92 ("comparable") appears 2 time.
# Word 93 ("comparison") appears 2 time.
# Word 94 ("complication") appears 14 time.
# Word 95 ("concern") appears 2 time.
# Word 96 ("conclusion") appears 4 time.
# Word 97 ("concomitantly") appears 2 time.
# Word 98 ("confirm") appears 6 time.
# Word 99 ("congenital") appears 2 time.
# Word 100 ("congestive") appears 4 time.
# Word 101 ("consider") appears 2 time.
# Word 102 ("consistent") appears 4 time.
# Word 103 ("consolidation") appears 4 time.
# Word 104 ("contact") appears 2 time.
# Word 105 ("contrast") appears 2 time.
# Word 106 ("cough") appears 6 time.
# Word 107 ("country") appears 4 time.
# Word 108 ("culture") appears 20 time.
# Word 109 ("cultured") appears 4 time.
# Word 110 ("daily") appears 2 time.
# Word 111 ("datum") appears 14 time.
# Word 112 ("death") appears 4 time.
# Word 113 ("december") appears 4 time.
# Word 114 ("define") appears 2 time.
# Word 115 ("demographic") appears 4 time.
# Word 116 ("department") appears 2 time.
# Word 117 ("describe") appears 2 time.
# Word 118 ("detect") appears 6 time.
# Word 119 ("develop") appears 4 time.
# Word 120 ("diagnose") appears 4 time.
# Word 121 ("diagnosis") appears 2 time.
# Word 122 ("diameter") appears 2 time.
# Word 123 ("die") appears 14 time.
# Word 124 ("difference") appears 2 time.
# Word 125 ("difficult") appears 2 time.
# Word 126 ("disc") appears 2 time.
# Word 127 ("disease") appears 10 time.
# Word 128 ("disorder") appears 2 time.
# Word 129 ("disparity") appears 2 time.
# Word 130 ("distress") appears 4 time.
# Word 131 ("droplet") appears 2 time.
# Word 132 ("e.g.") appears 12 time.
# Word 133 ("edema") appears 2 time.
# Word 134 ("effusion") appears 2 time.
# Word 135 ("elderly") appears 2 time.
# Word 136 ("emergency") appears 2 time.
# Word 137 ("endotracheal") appears 2 time.
# Word 138 ("enter") appears 2 time.
# Word 139 ("epidemiological") appears 2 time.
# Word 140 ("epidemiology") appears 6 time.
# Word 141 ("episode") appears 6 time.
# Word 142 ("evan") appears 2 time.
# Word 143 ("evidence") appears 2 time.
# Word 144 ("exact") appears 2 time.
# Word 145 ("examination") appears 2 time.
# Word 146 ("expect") appears 2 time.
# Word 147 ("explanation") appears 2 time.
# Word 148 ("exposure") appears 2 time.
# Word 149 ("facility") appears 2 time.
# Word 150 ("failure") appears 6 time.
# Word 151 ("fall") appears 6 time.
# Word 152 ("family") appears 2 time.
# Word 153 ("feature") appears 8 time.
# Word 154 ("febrile") appears 2 time.
# Word 155 ("fever") appears 8 time.
# Word 156 ("fibrosis") appears 2 time.
# Word 157 ("find") appears 2 time.
# Word 158 ("finding") appears 4 time.
# Word 159 ("fisher") appears 2 time.
# Word 160 ("follow") appears 10 time.
# Word 161 ("france") appears 2 time.
# Word 162 ("frequent") appears 2 time.
# Word 163 ("frequently") appears 4 time.
# Word 164 ("fry") appears 2 time.
# Word 165 ("gene") appears 2 time.
# Word 166 ("gestation") appears 2 time.
# Word 167 ("glucose") appears 2 time.
# Word 168 ("grade") appears 2 time.
# Word 169 ("gram") appears 2 time.
# Word 170 ("granular") appears 2 time.
# Word 171 ("group") appears 6 time.
# Word 172 ("grow") appears 2 time.
# Word 173 ("half") appears 4 time.
# Word 174 ("heart") appears 8 time.
# Word 175 ("hematologic") appears 2 time.
# Word 176 ("hemolytic") appears 2 time.
# Word 177 ("hemorrhage") appears 2 time.
# Word 178 ("herpe") appears 2 time.
# Word 179 ("high") appears 10 time.
# Word 180 ("highly") appears 2 time.
# Word 181 ("history") appears 6 time.
# Word 182 ("hope") appears 2 time.
# Word 183 ("hospital") appears 22 time.
# Word 184 ("hour") appears 2 time.
# Word 185 ("human") appears 2 time.
# Word 186 ("hypotension") appears 2 time.
# Word 187 ("hypoxemia") appears 2 time.
# Word 188 ("identification") appears 2 time.
# Word 189 ("identify") appears 8 time.
# Word 190 ("immunity") appears 2 time.
# Word 191 ("immunocompromise") appears 2 time.
# Word 192 ("immunocompromised") appears 12 time.
# Word 193 ("immunodeficiency") appears 2 time.
# Word 194 ("include") appears 6 time.
# Word 195 ("incubate") appears 2 time.
# Word 196 ("incubation") appears 2 time.
# Word 197 ("infant") appears 12 time.
# Word 198 ("infect") appears 2 time.
# Word 199 ("infected") appears 2 time.
# Word 200 ("infection") appears 78 time.
# Word 201 ("information") appears 6 time.
# Word 202 ("inpatient") appears 2 time.
# Word 203 ("inspect") appears 2 time.
# Word 204 ("instruction") appears 4 time.
# Word 205 ("international") appears 2 time.
# Word 206 ("intravascular") appears 2 time.
# Word 207 ("involve") appears 2 time.
# Word 208 ("isolate") appears 12 time.
# Word 209 ("january") appears 6 time.
# Word 210 ("king") appears 6 time.
# Word 211 ("know") appears 4 time.
# Word 212 ("laboratory") appears 2 time.
# Word 213 ("large") appears 2 time.
# Word 214 ("lasting") appears 2 time.
# Word 215 ("lavage") appears 2 time.
# Word 216 ("light") appears 2 time.
# Word 217 ("like") appears 2 time.
# Word 218 ("likely") appears 8 time.
# Word 219 ("long") appears 2 time.
# Word 220 ("low") appears 4 time.
# Word 221 ("lung") appears 4 time.
# Word 222 ("majority") appears 2 time.
# Word 223 ("malaise") appears 4 time.
# Word 224 ("malignancy") appears 2 time.
# Word 225 ("management") appears 2 time.
# Word 226 ("manifestation") appears 4 time.
# Word 227 ("manufacturer") appears 4 time.
# Word 228 ("medium") appears 4 time.
# Word 229 ("method") appears 2 time.
# Word 230 ("methods") appears 2 time.
# Word 231 ("microbiology") appears 4 time.
# Word 232 ("mild") appears 4 time.
# Word 233 ("military") appears 6 time.
# Word 234 ("minor") appears 4 time.
# Word 235 ("minute") appears 2 time.
# Word 236 ("mmhg") appears 2 time.
# Word 237 ("moderate") appears 4 time.
# Word 238 ("month") appears 6 time.
# Word 239 ("morphology") appears 2 time.
# Word 240 ("mortality") appears 10 time.
# Word 241 ("muscle") appears 2 time.
# Word 242 ("myalgia") appears 2 time.
# Word 243 ("mycoplasma") appears 12 time.
# Word 244 ("myocarditis") appears 2 time.
# Word 245 ("nasopharyngeal") appears 2 time.
# Word 246 ("nerve") appears 2 time.
# Word 247 ("nervous") appears 2 time.
# Word 248 ("newborn") appears 2 time.
# Word 249 ("nosocomial") appears 4 time.
# Word 250 ("objective") appears 1 time.
# Word 251 ("obstructive") appears 4 time.
# Word 252 ("obtain") appears 4 time.
# Word 253 ("occasion") appears 10 time.
# Word 254 ("occur") appears 14 time.
# Word 255 ("old") appears 4 time.
# Word 256 ("oppose") appears 4 time.
# Word 257 ("optic") appears 4 time.
# Word 258 ("orange") appears 2 time.
# Word 259 ("organ") appears 2 time.
# Word 260 ("organism") appears 18 time.
# Word 261 ("outbreak") appears 4 time.
# Word 262 ("outcome") appears 6 time.
# Word 263 ("outpatient") appears 4 time.
# Word 264 ("oxygen") appears 4 time.
# Word 265 ("package") appears 2 time.
# Word 266 ("pain") appears 2 time.
# Word 267 ("palsy") appears 2 time.
# Word 268 ("paper") appears 2 time.
# Word 269 ("partial") appears 2 time.
# Word 270 ("particularly") appears 2 time.
# Word 271 ("pathogen") appears 2 time.
# Word 272 ("patient") appears 108 time.
# Word 273 ("perform") appears 4 time.
# Word 274 ("period") appears 12 time.
# Word 275 ("person") appears 4 time.
# Word 276 ("physical") appears 2 time.
# Word 277 ("pleural") appears 2 time.
# Word 278 ("pneumonia") appears 68 time.
# Word 279 ("pneumoniae") appears 58 time.
# Word 280 ("pneumothorax") appears 2 time.
# Word 281 ("polymerase") appears 2 time.
# Word 282 ("population") appears 2 time.
# Word 283 ("positive") appears 8 time.
# Word 284 ("possible") appears 4 time.
# Word 285 ("premature") appears 2 time.
# Word 286 ("prematurely") appears 2 time.
# Word 287 ("preschool") appears 8 time.
# Word 288 ("present") appears 14 time.
# Word 289 ("presentation") appears 2 time.
# Word 290 ("pressure") appears 4 time.
# Word 291 ("previously") appears 2 time.
# Word 292 ("process") appears 2 time.
# Word 293 ("productive") appears 2 time.
# Word 294 ("profile") appears 2 time.
# Word 295 ("program") appears 2 time.
# Word 296 ("prompt") appears 2 time.
# Word 297 ("prove") appears 6 time.
# Word 298 ("psychosis") appears 2 time.
# Word 299 ("publication") appears 2 time.
# Word 300 ("publish") appears 4 time.
# Word 301 ("quarter") appears 2 time.
# Word 302 ("radiographic") appears 2 time.
# Word 303 ("radiological") appears 2 time.
# Word 304 ("rare") appears 8 time.
# Word 305 ("rarely") appears 2 time.
# Word 306 ("rash") appears 2 time.
# Word 307 ("rate") appears 4 time.
# Word 308 ("reaction") appears 2 time.
# Word 309 ("record") appears 4 time.
# Word 310 ("recover") appears 8 time.
# Word 311 ("recovery") appears 12 time.
# Word 312 ("recruit") appears 4 time.
# Word 313 ("relate") appears 2 time.
# Word 314 ("relatively") appears 8 time.
# Word 315 ("remain") appears 6 time.
# Word 316 ("require") appears 6 time.
# Word 317 ("respectively") appears 2 time.
# Word 318 ("respiratory") appears 48 time.
# Word 319 ("result") appears 6 time.
# Word 320 ("retinal") appears 2 time.
# Word 321 ("retrospective") appears 4 time.
# Word 322 ("review") appears 8 time.
# Word 323 ("riyadh") appears 4 time.
# Word 324 ("round") appears 6 time.
# Word 325 ("saturation") appears 2 time.
# Word 326 ("saudi") appears 14 time.
# Word 327 ("scarce") appears 2 time.
# Word 328 ("school") appears 12 time.
# Word 329 ("sciences") appears 2 time.
# Word 330 ("secretion") appears 2 time.
# Word 331 ("see") appears 2 time.
# Word 332 ("selection") appears 2 time.
# Word 333 ("sensitivity") appears 2 time.
# Word 334 ("septic") appears 2 time.
# Word 335 ("serological") appears 4 time.
# Word 336 ("severe") appears 4 time.
# Word 337 ("severity") appears 2 time.
# Word 338 ("shed") appears 2 time.
# Word 339 ("shock") appears 2 time.
# Word 340 ("show") appears 2 time.
# Word 341 ("sick") appears 2 time.
# Word 342 ("sign") appears 10 time.
# Word 343 ("similar") appears 2 time.
# Word 344 ("similarly") appears 2 time.
# Word 345 ("simplex") appears 2 time.
# Word 346 ("singly") appears 2 time.
# Word 347 ("slightly") appears 2 time.
# Word 348 ("small") appears 2 time.
# Word 349 ("social") appears 2 time.
# Word 350 ("sound") appears 2 time.
# Word 351 ("specie") appears 2 time.
# Word 352 ("specimen") appears 12 time.
# Word 353 ("spinal") appears 2 time.
# Word 354 ("spring") appears 4 time.
# Word 355 ("spss") appears 2 time.
# Word 356 ("sputum") appears 4 time.
# Word 357 ("square") appears 2 time.
# Word 358 ("stain") appears 2 time.
# Word 359 ("standard") appears 2 time.
# Word 360 ("standardized") appears 2 time.
# Word 361 ("statistic") appears 2 time.
# Word 362 ("statistical") appears 2 time.
# Word 363 ("steroid") appears 2 time.
# Word 364 ("student") appears 2 time.
# Word 365 ("study") appears 16 time.
# Word 366 ("subject") appears 2 time.
# Word 367 ("summarize") appears 4 time.
# Word 368 ("summer") appears 2 time.
# Word 369 ("symptom") appears 8 time.
# Word 370 ("syncytial") appears 4 time.
# Word 371 ("syndrome") appears 12 time.
# Word 372 ("system") appears 14 time.
# Word 373 ("systolic") appears 2 time.
# Word 374 ("table") appears 6 time.
# Word 375 ("tachycardia") appears 2 time.
# Word 376 ("teaching") appears 2 time.
# Word 377 ("technique") appears 2 time.
# Word 378 ("temperate") appears 4 time.
# Word 379 ("tendency") appears 2 time.
# Word 380 ("tertiary") appears 4 time.
# Word 381 ("test") appears 6 time.
# Word 382 ("therapy") appears 2 time.
# Word 383 ("thrombocytopenia") appears 2 time.
# Word 384 ("total") appears 2 time.
# Word 385 ("tract") appears 24 time.
# Word 386 ("transmissible") appears 2 time.
# Word 387 ("transmit") appears 2 time.
# Word 388 ("tray") appears 6 time.
# Word 389 ("treat") appears 2 time.
# Word 390 ("type") appears 2 time.
# Word 391 ("typical") appears 2 time.
# Word 392 ("underlie") appears 2 time.
# Word 393 ("underlying") appears 6 time.
# Word 394 ("university") appears 6 time.
# Word 395 ("unrelated") appears 2 time.
# Word 396 ("upper") appears 18 time.
# Word 397 ("usually") appears 4 time.
# Word 398 ("value") appears 2 time.
# Word 399 ("versus") appears 8 time.
# Word 400 ("viral") appears 2 time.
# Word 401 ("virtually") appears 2 time.
# Word 402 ("virus") appears 12 time.
# Word 403 ("week") appears 6 time.
# Word 404 ("white") appears 2 time.
# Word 405 ("winter") appears 2 time.
# Word 406 ("wish") appears 2 time.
# Word 407 ("year") appears 18 time.
# Word 408 ("yellow") appears 2 time.
# Word 409 ("young") appears 8 time.
# Word 90 ("community") appears 1 time.
# Word 2180 ("decide") appears 1 time.
# Word 9017 ("licence") appears 1 time.
# Word 10325 ("broadcasting") appears 1 time.

# %%
lda_model_tfidf = gensim.models.LdaMulticore(
    corpus, 
    num_topics=num_topics, 
    id2word=dictionary, 
    passes=passes, 
    iterations=iterations,
    minimum_probability=minimum_probability,
    random_state=2018,
    workers=4)

# %%
for idx, topic in lda_model_tfidf.print_topics(-1):
    print('Topic: {} Word: {}'.format(idx, topic))
# Out:
# Topic: 0 Word: 0.002*"tregs" + 0.001*"heater" + 0.001*"nina" + 0.001*"lamp" + 0.001*"isothermal" + 0.001*"prize" + 0.001*"citation" + 0.001*"padre" + 0.001*"foreigner" + 0.001*"heating"
# Topic: 1 Word: 0.004*"cat" + 0.001*"feline" + 0.001*"reassortant" + 0.001*"sofa" + 0.001*"gastroenteritis" + 0.001*"thai" + 0.001*"trout" + 0.001*"peru" + 0.001*"myocarditis" + 0.001*"seroprevalence"
# Topic: 2 Word: 0.003*"ifnα" + 0.001*"cd14" + 0.001*"peptidase" + 0.001*"amazon" + 0.001*"pneumonitis" + 0.001*"poliovirus" + 0.001*"emerging" + 0.001*"weather" + 0.001*"gibbs" + 0.001*"il-4"
# Topic: 3 Word: 0.003*"rabie" + 0.003*"tlr2" + 0.002*"tlr9" + 0.002*"myd88" + 0.002*"tlr" + 0.001*"ctl" + 0.001*"tlr7" + 0.001*"organizational" + 0.001*"adenosine" + 0.001*"ancestry"
# Topic: 4 Word: 0.001*"zanamivir" + 0.001*"traveller" + 0.001*"sensor" + 0.001*"electrode" + 0.001*"il-1" + 0.001*"chat" + 0.001*"games" + 0.001*"tomato" + 0.000*"placebo" + 0.000*"destination"
# Topic: 5 Word: 0.002*"ssdna" + 0.001*"integrin" + 0.001*"cap" + 0.001*"marr" + 0.000*"artist" + 0.000*"chaudhry" + 0.000*"stool" + 0.000*"dsdna" + 0.000*"invertebrate" + 0.000*"angiotensin"
# Topic: 6 Word: 0.002*"eosinophil" + 0.002*"nurse" + 0.001*"flock" + 0.001*"wear" + 0.001*"breakpoint" + 0.001*"cochlear" + 0.001*"victoria" + 0.001*"plague" + 0.001*"morley" + 0.001*"degranulation"
# Topic: 7 Word: 0.002*"reproductive" + 0.001*"a(h1n1" + 0.001*"pancreatitis" + 0.001*"ssrna" + 0.001*"mast" + 0.001*"autoantibody" + 0.000*"ship" + 0.000*"boonah" + 0.000*"painful" + 0.000*"maryland"
# Topic: 8 Word: 0.001*"patch" + 0.001*"fluke" + 0.001*"tetramer" + 0.001*"prostaglandin" + 0.001*"juvenile" + 0.001*"mismatch" + 0.000*"mainland" + 0.000*"aged" + 0.000*"highway" + 0.000*"avidity"
# Topic: 9 Word: 0.001*"ovine" + 0.001*"proteolysis" + 0.001*"sting" + 0.001*"trade" + 0.001*"toad" + 0.001*"google" + 0.001*"endo" + 0.001*"shark" + 0.001*"classification" + 0.001*"commonwealth"
# Topic: 10 Word: 0.001*"hoof" + 0.001*"ocular" + 0.001*"certificate" + 0.001*"connecticut" + 0.000*"bioterrorism" + 0.000*"malaysia" + 0.000*"ambient" + 0.000*"fox" + 0.000*"mango" + 0.000*"anthrax"
# Topic: 11 Word: 0.002*"scientific" + 0.002*"contig" + 0.001*"cgmmv" + 0.001*"melanoma" + 0.001*"worm" + 0.001*"sofa" + 0.001*"math" + 0.001*"disparity" + 0.001*"sv40" + 0.001*"orthopaedic"
# Topic: 12 Word: 0.005*"patient" + 0.004*"influenza" + 0.003*"protein" + 0.003*"pandemic" + 0.003*"sequence" + 0.003*"gene" + 0.003*"h1n1" + 0.002*"virus" + 0.002*"peptide" + 0.002*"child"
# Topic: 13 Word: 0.005*"" + 0.001*"paramyxovirus" + 0.001*"ip-10" + 0.001*"pneumococcal" + 0.001*"galactosidase" + 0.001*"ccl2" + 0.001*"snp" + 0.001*"flower" + 0.001*"benzene" + 0.001*"pup"
# Topic: 14 Word: 0.001*"microglia" + 0.001*"honey" + 0.001*"antidepressant" + 0.001*"whale" + 0.001*"roma" + 0.001*"zealand" + 0.001*"measle" + 0.001*"bee" + 0.001*"vegf" + 0.001*"lazio"
# Topic: 15 Word: 0.003*"exacerbation" + 0.002*"helicase" + 0.001*"ptsd" + 0.001*"fierce" + 0.001*"pessimism" + 0.001*"feeding" + 0.001*"transmembrane" + 0.001*"optimism" + 0.001*"ninja" + 0.001*"cabin"
# Topic: 16 Word: 0.003*"rage" + 0.001*"sirnas" + 0.001*"aphid" + 0.001*"cathepsin" + 0.001*"icam-1" + 0.001*"atpase" + 0.001*"walker" + 0.001*"acidification" + 0.001*"hawaii" + 0.001*"ubiquitination"
# Topic: 17 Word: 0.006*"frameshifting" + 0.004*"frameshift" + 0.004*"frameshifte" + 0.002*"slippery" + 0.002*"journal" + 0.001*"roller" + 0.001*"bottle" + 0.001*"codon" + 0.001*"lamb" + 0.001*"profession"
# Topic: 18 Word: 0.005*"respondent" + 0.004*"codon" + 0.003*"usage" + 0.002*"distancing" + 0.002*"psychological" + 0.002*"stockpile" + 0.002*"corticosteroid" + 0.002*"orf1" + 0.001*"paediatric" + 0.001*"herb"
# Topic: 19 Word: 0.006*"sirna" + 0.005*"recombination" + 0.005*"codon" + 0.004*"recipient" + 0.004*"coil" + 0.004*"transplant" + 0.003*"lane" + 0.003*"flag" + 0.003*"helix" + 0.003*"pneumoniae"
# Topic: 20 Word: 0.008*"denv" + 0.003*"pregnancy" + 0.002*"pregnant" + 0.002*"entropy" + 0.002*"kawasaki" + 0.001*"sialic" + 0.001*"mother" + 0.001*"honey" + 0.001*"shannon" + 0.001*"stalk"
# Topic: 21 Word: 0.013*"cell" + 0.009*"mouse" + 0.007*"lung" + 0.004*"cytokine" + 0.004*"replication" + 0.004*"expression" + 0.004*"anti" + 0.004*"hiv-1" + 0.004*"induce" + 0.004*"immune"
# Topic: 22 Word: 0.005*"chinese" + 0.004*"immunize" + 0.004*"complement" + 0.003*"macaque" + 0.003*"adhesion" + 0.003*"deficiency" + 0.003*"autoimmune" + 0.003*"milk" + 0.002*"monkey" + 0.002*"extracellular"
# Topic: 23 Word: 0.002*"iris" + 0.002*"sentinel" + 0.001*"bioassay" + 0.001*"abscess" + 0.001*"electrode" + 0.001*"satellite" + 0.001*"virological" + 0.001*"replicon" + 0.000*"lyssavirus" + 0.000*"biosensor"
# Topic: 24 Word: 0.003*"rdrp" + 0.003*"replicase" + 0.002*"ires" + 0.002*"termination" + 0.001*"clara" + 0.001*"schizophrenia" + 0.001*"outdoor" + 0.001*"perch" + 0.001*"anthrax" + 0.001*"terrorist"
# Topic: 25 Word: 0.001*"triage" + 0.001*"replicon" + 0.001*"cyclosporine" + 0.001*"rear" + 0.001*"contamination" + 0.001*"mallard" + 0.001*"stair" + 0.000*"pneumococcal" + 0.000*"philadelphia" + 0.000*"hunting"
# Topic: 26 Word: 0.004*"mosquito" + 0.004*"lineage" + 0.003*"tick" + 0.003*"lamp" + 0.003*"snp" + 0.002*"insertion" + 0.002*"divergence" + 0.002*"differentiation" + 0.002*"astrocyte" + 0.002*"sheep"
# Topic: 27 Word: 0.003*"erk1/2" + 0.002*"mapk" + 0.001*"slam" + 0.001*"egfp" + 0.001*"altitude" + 0.001*"chaos" + 0.001*"orleans" + 0.001*"insulin" + 0.001*"puma" + 0.001*"lion"
# Topic: 28 Word: 0.001*"seller" + 0.001*"wasp" + 0.001*"coronavirus" + 0.001*"fertility" + 0.001*"sulfur" + 0.001*"medic" + 0.001*"titre" + 0.000*"exhaust" + 0.000*"blower" + 0.000*"touch"
# Topic: 29 Word: 0.002*"traveler" + 0.001*"cyst" + 0.001*"mirna" + 0.001*"optic" + 0.001*"hopping" + 0.001*"nerve" + 0.001*"axonal" + 0.001*"sumo" + 0.001*"agonist" + 0.001*"retention"

# %%
topics = lda_model_tfidf.get_topics()
print(topics.shape)
print(topics[1,:])
print(max(topics[1,:]), "<-- should be the first word of topic 1 from above")
print(min(topics[1,:]))
print(sum(topics[1,:]))
print()
topic_terms = lda_model_tfidf.get_topic_terms(1, topn=5)
for term_id, prob in topic_terms:
    print(f"Term: {dictionary[term_id]}, Term Id: {term_id}, Prob: {prob:.2%}")
# Out:
# (30, 21272)
# [4.6077959e-05 4.6077272e-05 4.6080637e-05 ... 4.6077272e-05 4.6077272e-05
#  4.6077272e-05]
# 0.0035455448 <-- should be the first word of topic 1 from above
# 4.607727e-05
# 1.0000000487998477
#
# Term: cat, Term Id: 7346, Prob: 0.35%
# Term: feline, Term Id: 9064, Prob: 0.12%
# Term: reassortant, Term Id: 8897, Prob: 0.11%
# Term: sofa, Term Id: 9311, Prob: 0.10%
# Term: gastroenteritis, Term Id: 6515, Prob: 0.09%

# %%
lda_model_tfidf_2 = gensim.models.LdaMulticore(
    corpus, 
    num_topics=num_topics, 
    id2word=dictionary, 
    passes=passes, 
    iterations=iterations,
    minimum_probability=minimum_probability,
    random_state=2023,
    workers=4)

# %%
for idx, topic in lda_model_tfidf_2.print_topics(-1):
    print('Topic: {} Word: {}'.format(idx, topic))

# %%
topics = lda_model_tfidf_2.get_topics()
for term_id, prob in topic_terms:
    max_other = max([topic_probs[term_id] for topic_probs in topics])
    print(f"Term: {dictionary[term_id]}, Prob: {prob:.2%}, Other Prob: {max_other:.2%}")

# %%
lda_model_tfidf_comp = gensim.models.LdaMulticore(
    corpus_comp, 
    num_topics=num_topics, 
    id2word=dictionary, 
    passes=passes, 
    iterations=iterations,
    minimum_probability=minimum_probability,
    random_state=2023,
    workers=4)

# %%
for idx, topic in lda_model_tfidf_2.print_topics(-1):
    print('Topic: {} Word: {}'.format(idx, topic))

# %%
lda_1_path = os.path.join(model_dir, "lda_1")
lda_2_path = os.path.join(model_dir, "lda_2")
lda_comp_path = os.path.join(model_dir, "lda_comp")

lda_model_tfidf.save(lda_1_path)
lda_model_tfidf_2.save(lda_2_path)
lda_model_tfidf_comp.save(lda_comp_path)
